# %% [markdown]
# <a href="https://colab.research.google.com/github/felipe-augusto93/BootcampDataScience2021/blob/main/Notebooks/AluraDataScience2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I - Aquisição e Leitura de Dados Reais

# %% [markdown]
# ## AULA

# %%
import pandas as pd

# %%
URL_1 = 'https://raw.githubusercontent.com/felipe-augusto93/BootcampDataScience2021/main/Data/dataset_UnFed_Y-M_total.csv'
URL_2 = 'https://raw.githubusercontent.com/felipe-augusto93/BootcampDataScience2021/main/Data/dataset_UnFed_Y-M-A_total.csv'

# %%
dataset1 = pd.read_csv(URL_1, encoding="ISO-8859-1", skiprows= 3, sep= ";", skipfooter= 12, thousands=".", decimal=",")
dataset1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#   Unidade da Federação     2008/Jan  ...     2021/Mar         Total
# 0          11 Rondônia   1388528.39  ...  11023309.47  9.964113e+08
# 1              12 Acre    902416.00  ...   4077045.92  4.500485e+08
# 2          13 Amazonas   4735529.42  ...  22032176.22  1.917248e+09
# 3           14 Roraima    657889.53  ...   3985530.08  3.288770e+08
# 4              15 Pará  18864744.11  ...  33276392.89  4.705309e+09
#
# [5 rows x 161 columns]

# %%
dataset1.tail()
# Out:
#      Unidade da Federação     2008/Jan  ...      2021/Mar         Total
# 22   43 Rio Grande do Sul  30931325.46  ...  1.301552e+08  1.276439e+10
# 23  50 Mato Grosso do Sul   5377392.11  ...  2.516820e+07  2.324525e+09
# 24         51 Mato Grosso   4795299.01  ...  1.961103e+07  2.180120e+09
# 25               52 Goiás  15310637.29  ...  4.559269e+07  4.973574e+09
# 26    53 Distrito Federal   4745919.19  ...  3.183192e+07  2.592423e+09
#
# [5 rows x 161 columns]

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 161 entries, Unidade da Federação to Total
# dtypes: float64(159), object(2)
# memory usage: 34.1+ KB

# %%
#Mudou a forma de impressão dos dados. Assim, mudou de notação científica (padrão do PANDAS) para duas casa deciamis (.2f)
pd.options.display.float_format = "{:.2f}".format
dataset1.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Dez     53377763.15
# 2021/Jan     56073748.02
# 2021/Fev     55578233.31
# 2021/Mar     62502301.42
# Total      6388213338.48
# Length: 159, dtype: float64

# %% [markdown]
# * DESAFIO: Selecionar os valores da coluna 2008/Jan

# %%
#Isso é chamado de "Série"
dataset1['2008/Jan']
# Out:
# 0     1388528.39
# 1      902416.00
# 2     4735529.42
# 3      657889.53
# 4    18864744.11
# 5     1120973.34
# 6     3441592.69
# 7    10723506.39
# 8     7985142.43
# 9    15539821.90
# 10    5947814.08
# 11   10723002.45
# 12   14393949.89
# 13    6243726.32
# 14    2780750.11
# 15   21211522.47
# 16   45671659.76
# 17    5456723.98
# 18   23025258.52
# 19   91678473.48
# 20   38266347.46
# 21   16504913.45
# 22   30931325.46
# 23    5377392.11
# 24    4795299.01
# 25   15310637.29
# 26    4745919.19
# Name: 2008/Jan, dtype: float64

# %%
dataset1['2008/Jan'].mean()
# Out:
# 15126846.638148146

# %%
#Primeiro Plot de gráfico. Tá ruim assim!
dataset1.plot(x= "Unidade da Federação", y= "2008/Jan")

# %%
#Segundo Plot. Melhor vizualização nesse tipo (bar), mas ainda está ruim.
dataset1.plot(x= "Unidade da Federação", y= "2008/Jan", kind= "bar")

# %%
#Aumentou o tamanho (figsize)
dataset1.plot(x= "Unidade da Federação", y= "2008/Jan", kind= "bar", figsize= (9,6))

# %%
# Importar a biblioteca MATPLOTLIB para melhorar o gráfico
import matplotlib.pyplot as plt

# Importar o pacote/biblioteca 'ticker formmater' para alterar os valores do eixo Y
# url = https://matplotlib.org/stable/gallery/ticks_and_spines/tick-formatters.html
import matplotlib.ticker as ticker

# %%
axis = dataset1.plot(x= "Unidade da Federação", y= "2008/Jan", kind= "bar", figsize= (9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}") )
plt.title("Gastos por Unidade da Federação em Janeiro de 2008")
# Out:
# Text(0.5, 1.0, 'Gastos por Unidade da Federação em Janeiro de 2008')

# %% [markdown]
# ## DESAFIO: Faça a mesma análise realizada em aula, porém para o mês mais recente.

# %%
axis2 = dataset1.plot(x= "Unidade da Federação", y= "2021/Mar", kind= "bar", figsize= (10,7))
axis2.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}") )
plt.title("Gastos por Unidade da Federação em Março de 2021")
# Out:
# Text(0.5, 1.0, 'Gastos por Unidade da Federação em Março de 2021')

# %% [markdown]
# # II - Primeiras Visualizações de Dados

# %% [markdown]
# ## AULA

# %%
# Foi refeito tudo da Aula I, mas utlizando-se do dataset com ANO/MÊS de ATENDIMENTO
# Puxei lá no início o novo dataset como "URL_2" e rodei tudo igual
dataset2 = pd.read_csv(URL_2, encoding="ISO-8859-1", skiprows= 3, sep= ";", skipfooter= 12, thousands=".", decimal=",")
dataset2.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2021/Fev    2021/Mar         Total
# 0          11 Rondônia        -        -  ...  6039419.59  4732441.04  996411254.68
# 1              12 Acre        -        -  ...  2272733.90  1137341.65  450048530.47
# 2          13 Amazonas        -        -  ... 13679358.06  6799060.80 1917247936.05
# 3           14 Roraima        -        -  ...  3044798.77  2381844.31  328876965.09
# 4              15 Pará        -        -  ... 23343222.94 13069564.31 4705309002.29
#
# [5 rows x 287 columns]

# %%
dataset2.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...    2021/Mar          Total
# 22   43 Rio Grande do Sul        -  ... 37798832.80 12764391179.92
# 23  50 Mato Grosso do Sul        -  ...  4035989.77  2324525096.33
# 24         51 Mato Grosso        -  ...  8835890.09  2180119781.15
# 25               52 Goiás        -  ... 24867001.02  4973572261.43
# 26    53 Distrito Federal        -  ... 14731938.43  2592422853.56
#
# [5 rows x 287 columns]

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 287 entries, Unidade da Federação to Total
# dtypes: float64(165), object(122)
# memory usage: 60.7+ KB

# %%
#Mudou a forma de impressão dos dados. Assim, mudou de notação científica (padrão do PANDAS) para duas casa deciamis (.2f)
pd.options.display.float_format = "{:.2f}".format
dataset2.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %% [markdown]
# * DESAFIO: Selecionar os valores da coluna 2008/Jan

# %%
#Isso é chamado de "Série"
dataset2['2008/Jan']
# Out:
# 0       1829559.71
# 1       1731744.62
# 2      11419210.08
# 3        808448.39
# 4      21762104.16
# 5       1329876.61
# 6       5136474.61
# 7      21551600.33
# 8      11375419.37
# 9      32444328.54
# 10     11763899.23
# 11     16599004.84
# 12     51261210.58
# 13     16568724.64
# 14      5439985.99
# 15     73947845.87
# 16    206208080.90
# 17     16212109.41
# 18    251511992.03
# 19   1038067423.15
# 20     58081334.45
# 21     53034384.67
# 22     51064610.03
# 23      8301006.10
# 24      8213438.64
# 25     75039013.46
# 26     10561085.46
# Name: 2008/Jan, dtype: float64

# %%
dataset2['2008/Jan'].mean()
# Out:
# 76343107.9951852

# %%
#Primeiro Plot de gráfico. Tá ruim assim!
dataset2.plot(x= "Unidade da Federação", y= "2008/Jan")

# %%
#Segundo Plot. Melhor vizualização nesse tipo (bar), mas ainda está ruim.
dataset2.plot(x= "Unidade da Federação", y= "2008/Jan", kind= "bar")

# %%
#Aumentou o tamanho (figsize)
dataset2.plot(x= "Unidade da Federação", y= "2008/Jan", kind= "bar", figsize= (9,6))

# %%
# Importar a biblioteca MATPLOTLIB para melhorar o gráfico
import matplotlib.pyplot as plt

# Importar o pacote/biblioteca 'ticker formmater' para alterar os valores do eixo Y
# url = https://matplotlib.org/stable/gallery/ticks_and_spines/tick-formatters.html
import matplotlib.ticker as ticker

# %%
axis = dataset2.plot(x= "Unidade da Federação", y= "2008/Jan", kind= "bar", figsize= (9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}") )
plt.title("Gastos por Unidade da Federação em Janeiro de 2008")
# Out:
# Text(0.5, 1.0, 'Gastos por Unidade da Federação em Janeiro de 2008')

# %% [markdown]
# ## Aqui começa a Aula 2

# %%
# Aqui é um slice/pedaço do dataset2
dataset2 [["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
# Para fazer uma comparação, é necessário encontrar meses tem que valores para esse fim.
# A função ".mean()", por padrão, puxa apenas as colunas que tem valores para fazer as médias.
# Assim:
dataset2.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
# O comando ".mean()" puxa apenas as colunas que tem todos os campos preenchidos;
# O comando ".index" cria uma série imutável. Então, é necessário transformar em uma lista de Python (".tolist()")
## colunas_com_dados = dataset2.mean().index
## colunas_com_dados

# %%
colunas_com_dados = dataset2.mean().index.tolist()
colunas_com_dados.insert(0, "Unidade da Federação")
colunas_com_dados
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
# Agora é fazer um slice baseado nas colunas com dados
# Lembrando que nesse momento está sendo utilizado a tática de "ignorar os dados faltantes"
# Caso não se posso ignorar esses dados faltantes, pode-se: fazer um tratamento de dados no Excel, completar as lacunas com um mesmo valor já existente ou tirar a
# média das existentes e completar as lacunas da coluna com essa média
dados_com_undfed = dataset2[colunas_com_dados]
dados_com_undfed.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Mar         Total
# 0          11 Rondônia   4209.37  ...  4732441.04  996411254.68
# 1              12 Acre  10470.07  ...  1137341.65  450048530.47
# 2          13 Amazonas  35752.72  ...  6799060.80 1917247936.05
# 3           14 Roraima   4785.91  ...  2381844.31  328876965.09
# 4              15 Pará 181159.29  ... 13069564.31 4705309002.29
#
# [5 rows x 166 columns]

# %%
dados_com_index = dados_com_undfed.set_index("Unidade da Federação")
dados_com_index.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Mar         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  4732441.04  996411254.68
# 12 Acre               10470.07  14001.71  ...  1137341.65  450048530.47
# 13 Amazonas           35752.72  45570.64  ...  6799060.80 1917247936.05
# 14 Roraima             4785.91  11858.63  ...  2381844.31  328876965.09
# 15 Pará              181159.29 433414.74  ... 13069564.31 4705309002.29
#
# [5 rows x 165 columns]

# %%
dados_com_index["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
# Localizar a linha cujo índice é "12 Acre"
dados_com_index.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
# Inverter Colunas com Linhas do Index
dados_com_index.T.head()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Dez               9003402.23  ...          22552034.04
# 2021/Jan               8414690.60  ...          22573869.50
# 2021/Fev               6039419.59  ...          19004029.87
# 2021/Mar               4732441.04  ...          14731938.43
# Total                996411254.68  ...        2592422853.56
#
# [5 rows x 27 columns]

# %%
dados_com_index.T.tail()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Dez               9003402.23  ...          22552034.04
# 2021/Jan               8414690.60  ...          22573869.50
# 2021/Fev               6039419.59  ...          19004029.87
# 2021/Mar               4732441.04  ...          14731938.43
# Total                996411254.68  ...        2592422853.56
#
# [5 rows x 27 columns]

# %%
#Gráfico saiu estranho, pois a linha do "Total" tá dando um valor alto demais. É preciso tirar essa linha
dados_com_index.T.plot(figsize= (10,7))

# %%
dados_sem_total = dados_com_index.drop("Total", axis= 1)
dados_sem_total.tail()
# Out:
#                         2007/Ago   2007/Set  ...    2021/Fev    2021/Mar
# Unidade da Federação                         ...
# 43 Rio Grande do Sul  1049252.33 3182913.14  ... 84404640.00 37798832.80
# 50 Mato Grosso do Sul  199556.12  573675.41  ... 11428462.42  4035989.77
# 51 Mato Grosso          63562.50  232444.62  ... 13207979.82  8835890.09
# 52 Goiás               179395.82  418053.58  ... 32253788.65 24867001.02
# 53 Distrito Federal    191951.47  769966.25  ... 19004029.87 14731938.43
#
# [5 rows x 164 columns]

# %%
dados_sem_total.T.plot(figsize= (10,7))

# %% [markdown]
# ## Desafio 01: Reposicionar a legenda do gráfico em uma posição mais adequada

# %%
# Anatomy of a figure: https://matplotlib.org/stable/gallery/showcase/anatomy.html
# Legend location: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#legend-location

# O argumento "bbox_to_anchor= (1.01, 1)" coloca as legendas para fora do gráfico
# A real é: guarda essa linha de código pq é chato ficar arrumando a localização da legenda

dados_sem_total.T.plot(figsize= (20,14))
plt.legend(bbox_to_anchor= (1.01, 1), borderaxespad= 0, loc="upper left")
plt.title("Valor Total de Gastos por Data de Atedimento")
# Out:
# Text(0.5, 1.0, 'Valor Total de Gastos por Data de Atedimento')

# %%
#axis2 = dataset1.plot(x= "Unidade da Federação", y= "2021/Mar", kind= "bar", figsize= (10,7))
#axis2.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}") )
#plt.title("Gastos por Unidade da Federação em Março de 2021")

# %% [markdown]
# ## Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência

# %% [markdown]
# # III - Manipulação de Dados

# %% [markdown]
# # IV - Análise de Gráficos e Exploração de Hipóteses

# %% [markdown]
# # V - Manipulação e Interpretação de Gráficos
